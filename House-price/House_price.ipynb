# %% [markdown]
# <a href="https://colab.research.google.com/github/raywu60kg/kaggles/blob/master/House-price/House_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # House Price
# Use the kaggle dataset [House Prices: Advanced Regression Techniques](https://www.kaggle.com/c/house-prices-advanced-regression-techniques) and package pycaret to build the prediction model.

# %%
# !pip install pycaret==2.0 >> /dev/null

# %%
# Put our kaggle api token (kaggle.json)
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-737f11fb-62ae-4b69-abd1-76e7668585ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-737f11fb-62ae-4b69-abd1-76e7668585ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json

# %%
import json
with open('kaggle.json') as f:
  kaggle_api = json.load(f)

# %%
import os
os.environ['KAGGLE_USERNAME'] = kaggle_api['username']
os.environ['KAGGLE_KEY'] = kaggle_api['key']

# %%
# !kaggle competitions download -c house-prices-advanced-regression-techniques
# Out:
# ...
# test.csv: Skipping, found more recently modified local copy (use --force to force download)
# data_description.txt: Skipping, found more recently modified local copy (use --force to force download)
# train.csv: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
import pandas as pd

# %%
data = pd.read_csv("train.csv")

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
from pycaret.regression import *
reg1 = setup(
    data, 
    target="SalePrice", 
    session_id=123, 
    log_experiment=True, 
    experiment_name="house_price", 
    silent=True, 
    normalize=True,
    normalize_method="robust",
    feature_selection=True,
    remove_outliers=True)
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
#     #T_3d414e94_dbb8_11ea_9cdd_0242ac1c0002row4_col1 {
#             background-color:  yellow;
#         }    #T_3d414e94_dbb8_11ea_9cdd_0242ac1c0002row15_col1 {
#             background-color:  yellow;
#         }    #T_3d414e94_dbb8_11ea_9cdd_0242ac1c0002row26_col1 {
#             background-color:  yellow;
#         }    #T_3d414e94_dbb8_11ea_9cdd_0242ac1c0002row37_col1 {
#             background-color:  yellow;
#         }</style><table id="T_3d414e94_dbb8_11ea_9cdd_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3d414e94_dbb8_11ea_9cdd_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
lightgbm_model = create_model("lightgbm")
# Out:
# <style  type="text/css" >
#     #T_3ffba576_dbb8_11ea_9cdd_0242ac1c0002row10_col0 {
#             background:  yellow;
#         }    #T_3ffba576_dbb8_11ea_9cdd_0242ac1c0002row10_col1 {
#             background:  yellow;
#         }    #T_3ffba576_dbb8_11ea_9cdd_0242ac1c0002row10_col2 {
#             background:  yellow;
#         }    #T_3ffba576_dbb8_11ea_9cdd_0242ac1c0002row10_col3 {
#             background:  yellow;
#         }    #T_3ffba576_dbb8_11ea_9cdd_0242ac1c0002row10_col4 {
#             background:  yellow;
#         }    #T_3ffba576_dbb8_11ea_9cdd_0242ac1c0002row10_col5 {
#             background:  yellow;
# ...

# %%
tuned_lightgbm_model = tune_model(lightgbm_model, round=4, optimize = "RMSE")
# Out:
# <style  type="text/css" >
#     #T_472d6686_dbb8_11ea_9cdd_0242ac1c0002row10_col0 {
#             background:  yellow;
#         }    #T_472d6686_dbb8_11ea_9cdd_0242ac1c0002row10_col1 {
#             background:  yellow;
#         }    #T_472d6686_dbb8_11ea_9cdd_0242ac1c0002row10_col2 {
#             background:  yellow;
#         }    #T_472d6686_dbb8_11ea_9cdd_0242ac1c0002row10_col3 {
#             background:  yellow;
#         }    #T_472d6686_dbb8_11ea_9cdd_0242ac1c0002row10_col4 {
#             background:  yellow;
#         }    #T_472d6686_dbb8_11ea_9cdd_0242ac1c0002row10_col5 {
#             background:  yellow;
# ...

# %% [markdown]
# ## Plot Model

# %%
plot_model(tuned_lightgbm_model, plot='residuals')

# %%
plot_model(tuned_lightgbm_model, plot="feature")

# %%
plot_model(tuned_lightgbm_model, plot="learning")

# %% [markdown]
# ## Predict

# %%
test_data = pd.read_csv("test.csv")

# %%
predictions = predict_model(tuned_lightgbm_model, data=test_data)
predictions.head()
# Out:
#      Id  MSSubClass MSZoning  ...  SaleType  SaleCondition        Label
# 0  1461          20       RH  ...        WD         Normal  132017.7137
# 1  1462          20       RL  ...        WD         Normal  158090.2408
# 2  1463          60       RL  ...        WD         Normal  182251.3036
# 3  1464          60       RL  ...        WD         Normal  196102.8178
# 4  1465         120       RL  ...        WD         Normal  170487.1335
#
# [5 rows x 81 columns]

# %%
# !ls
# Out:
#  catboost_info	        kaggle.json   sample_data	      test.csv
#  data_description.txt   logs.log      sample_submission.csv   train.csv
# 'kaggle (1).json'       mlruns	      submission.csv

# %%
submission = pd.read_csv("sample_submission.csv")

# %%
submission["SalePrice"] = predictions["Label"]

# %%
submission.head()
# Out:
#      Id    SalePrice
# 0  1461  132017.7137
# 1  1462  158090.2408
# 2  1463  182251.3036
# 3  1464  196102.8178
# 4  1465  170487.1335

# %%
submission.to_csv('/content/submission.csv', index=False)

# %%
# !kaggle competitions submit -c house-prices-advanced-regression-techniques -f submission.csv -m "my_submission"
# Out:
# ...
# 100% 24.0k/24.0k [00:00<00:00, 115kB/s]
# Successfully submitted to House Prices: Advanced Regression Techniques

# %% [markdown]
# ## Refrerence
# [Pycaret tutorial](https://pycaret.org/tutorial/)
